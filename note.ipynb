# %%
import numpy as np 
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
np.__version__, pd.__version__, plt.__version__
# Out:
# ('2.3.3', '2.3.2', '3.10.6')

# %%
sns.__version__
# Out:
# '0.13.2'
